# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june['Temperature'],
    ds_climate_nearest_stacked_june['Temperature'].mean(),
    ds_climate_nearest_stacked_june['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june['Temperature'].mean(),
        ds_aws_stacked_june['Temperature'].std(),
    )

# %%
c_corrected
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]])

# %%
c_corrected.shape
# Out:
# (456, 219)

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )

# %%
c_corrected
# Out:
# array([         nan,          nan,          nan,          nan,
#                 nan, -23.6044262 ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.41130784,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.28173221,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.11337722,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -27.13186844,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.51421411,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -22.12443119,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.87051821,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -30.60628157,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -27.08623904,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -23.3854354 ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.974761  ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.09104243,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.74289219,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.81000398,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.83028644,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.85121512,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -22.45210795,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -23.79970317,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.54024235,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.66217848,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.49943428,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.81261867,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -23.20459619,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.94115081,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.46214624,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.95394606,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -21.78006697,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.62006277,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -28.51459721,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -24.49727291,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.21772768,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.28719519,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -27.2085478 ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -25.63901954,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -28.2277366 ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -26.2553374 ,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan,          nan,          nan,          nan,
#                 nan, -23.2954556 ,          nan,          nan,
#                 nan,          nan,          nan,          nan])

# %%
c_corrected.shape
# Out:
# (456,)

# %%
month = 6 
station = 'Manuela'
ds_climate_nearest_stacked_june = ds_climate_nearest_stacked.where(
    ds_climate_nearest_stacked['month']==month,drop=True))

ds_aws_stacked_june = ds_aws_stacked.where(
    ds_aws_stacked['Month']==month,drop=True))

fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

ds_aws_stacked_june.sel(Station=station).to_dataframe()[['Temperature']].hist(bins=12,
                                         ax=ax,
                                         edgecolor='k',
                                         linewidth=0.2,
                                         grid=False,
                                         density=1,
                                         alpha=0.7,
                                         label = 'Weather Station',
                                         )
ds_climate_nearest_stacked_june.sel(Nearest_Station=station).to_dataframe()[['Temperature']].hist(bins=12,
                                         ax=ax,
                                         edgecolor='k',
                                         linewidth=0.2,
                                         grid=False,
                                         density=1,
                                         alpha=0.7,
                                        label = 'Climate Model',
                                         )
ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')
ax.set_title('')
ax.set_xlabel('Temperature')
ax.set_ylabel('Density')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#   Cell In[40], line 5
#     ds_climate_nearest_stacked['month']==month,drop=True))
#                                                          ^
# SyntaxError: unmatched ')'

# %%
month = 6 
station = 'Manuela'
ds_climate_nearest_stacked_june = ds_climate_nearest_stacked.where(
    ds_climate_nearest_stacked['month']==month,drop=True)

ds_aws_stacked_june = ds_aws_stacked.where(
    ds_aws_stacked['Month']==month,drop=True)

fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

ds_aws_stacked_june.sel(Station=station).to_dataframe()[['Temperature']].hist(bins=12,
                                         ax=ax,
                                         edgecolor='k',
                                         linewidth=0.2,
                                         grid=False,
                                         density=1,
                                         alpha=0.7,
                                         label = 'Weather Station',
                                         )
ds_climate_nearest_stacked_june.sel(Nearest_Station=station).to_dataframe()[['Temperature']].hist(bins=12,
                                         ax=ax,
                                         edgecolor='k',
                                         linewidth=0.2,
                                         grid=False,
                                         density=1,
                                         alpha=0.7,
                                        label = 'Climate Model',
                                         )
ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')
ax.set_title('')
ax.set_xlabel('Temperature')
ax.set_ylabel('Density')
plt.legend()
plt.tight_layout()
plt.show()

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )

# %%
c_corrected
# Out:
# array([-23.6044262 , -24.41130784, -25.28173221, -25.11337722,
#        -27.13186844, -25.51421411, -22.12443119, -24.87051821,
#        -30.60628157, -27.08623904, -23.3854354 , -24.974761  ,
#        -25.09104243, -26.74289219, -26.81000398, -26.83028644,
#        -25.85121512, -22.45210795, -23.79970317, -26.54024235,
#        -24.66217848, -25.49943428, -26.81261867, -23.20459619,
#        -25.94115081, -26.46214624, -24.95394606, -21.78006697,
#        -25.62006277, -28.51459721, -24.49727291, -25.21772768,
#        -25.28719519, -27.2085478 , -25.63901954, -28.2277366 ,
#        -26.2553374 , -23.2954556 ])

# %%
ds_climate_nearest_stacked_june
# Out:
# <xarray.Dataset> Size: 397kB
# Dimensions:                (Time: 38, Nearest_Station: 219)
# Coordinates:
#     Model                  <U9 36B 'MAR(ERA5)'
#   * Time                   (Time) int64 304B 18 30 42 54 66 ... 426 438 450 462
#     latitude               (Nearest_Station) float64 2kB ...
#     longitude              (Nearest_Station) float64 2kB ...
#     month                  (Time) int64 304B 6 6 6 6 6 6 6 6 ... 6 6 6 6 6 6 6 6
#     year                   (Time) int64 304B 1981 1982 1983 ... 2016 2017 2018
#     glon                   (Nearest_Station) float64 2kB ...
#     glat                   (Nearest_Station) float64 2kB ...
#     grid_longitude         (Nearest_Station) float64 2kB ...
#     grid_latitude          (Nearest_Station) float64 2kB ...
#   * Nearest_Station        (Nearest_Station) <U22 19kB 'AGO Site' ... 'aws17'
# Data variables:
#     Temperature            (Time, Nearest_Station) float64 67kB -34.61 ... -1...
#     LSM                    (Nearest_Station, Time) float32 33kB 1.0 1.0 ... 1.0
#     Elevation              (Nearest_Station, Time) float64 67kB 1.49e+03 ... ...
#     Latitude               (Nearest_Station, Time) float64 67kB -77.48 ... -6...
#     Mean Temperature       (Nearest_Station, Time) float64 67kB -25.48 ... -7...
#     Mean June Temperature  (Nearest_Station, Time) float64 67kB -32.02 ... -1...

# %%
ds_climate_nearest_stacked.sel(Nearest_Station = station).where(ds_climate_nearest_stacked['month']==month,drop=True)['Temperature']
# Out:
# <xarray.DataArray 'Temperature' (Time: 38)> Size: 304B
# array([-19.75763995, -20.56859185, -21.44340701, -21.27420277,
#        -23.30287613, -21.67706165, -18.27017921, -21.03011867,
#        -26.79481569, -23.25701655, -19.53754447, -21.13488731,
#        -21.25175531, -22.91193772, -22.97938805, -22.99977282,
#        -22.01576264, -18.59950891, -19.95390198, -22.70826563,
#        -20.82072799, -21.66220727, -22.98201593, -19.35579303,
#        -22.10615201, -22.62977556, -21.11396737, -17.92407786,
#        -21.78344426, -24.69257998, -20.65499056, -21.37907962,
#        -21.44889755, -23.3799423 , -21.80249666, -24.40427232,
#        -22.42192349, -19.44711077])
# Coordinates:
#     Model            <U9 36B 'MAR(ERA5)'
#   * Time             (Time) int64 304B 18 30 42 54 66 78 ... 414 426 438 450 462
#     latitude         float64 8B ...
#     longitude        float64 8B ...
#     month            (Time) int64 304B 6 6 6 6 6 6 6 6 6 6 ... 6 6 6 6 6 6 6 6 6
#     year             (Time) int64 304B 1981 1982 1983 1984 ... 2016 2017 2018
#     glon             float64 8B ...
#     glat             float64 8B ...
#     grid_longitude   float64 8B ...
#     grid_latitude    float64 8B ...
#     Nearest_Station  <U22 88B 'Manuela'

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )


fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

station = 'Manuela'
# station = 'Byrd'

ax.plot(x=ds_climate_nearest_stacked_june['Time'],
        y=c_corrected,
        alpha=0.7,
        label='Climate Model',
        marker='x',
        ms=1,
        color='tab:orange',
        linewidth=1.0)

ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                hue='Station',
                                                                                                alpha=0.7,
                                                                                                label='Weather Station',
                                                                                                marker='x',
                                                                                                ms=1,
                                                                                                color='tab:blue',
                                                                                                linewidth=1.5)

ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')

ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)#,rotation = 90)
ax.set_ylabel('Temperature')
ax.set_xlabel('Time')
ax.legend()
ax.set_title('')

plt.tight_layout()
plt.show()















ds_climate_nearest_stacked_june['Corrected_Temperature'] = (
    ('Time'),
    c_corrected,
)

ds_climate_coarse_june_stacked_landonly['exp_truth_posterior_predictive_realisations_dualprocess_mean'] = (
    ('X'),
    scenario['truth_posterior_predictive_realisations_dualprocess_mean'].mean(axis=0))

fig, axs = plt.subplots(2, 1, figsize=(10, 7), dpi=300)



for ax,station in zip(axs,['Manuela','Byrd']):
    ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                    hue='Station',
                                                                                                    alpha=0.7,
                                                                                                    label='Weather Station',
                                                                                                    marker='x',
                                                                                                    ms=2)
    ds_climate_nearest_stacked.sel(Nearest_Station = station).where(ds_climate_nearest_stacked['month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                                                    hue='Station',
                                                                                                                                    alpha=0.7,
                                                                                                                                    label='Climate Model',
                                                                                                                                    marker='x',
                                                                                                                                    ms=2)

    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)#,rotation = 90)
    ax.set_ylabel('Temperature')
    ax.set_xlabel('Time')
    ax.legend()
    ax.set_title('')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 24
#      21 station = 'Manuela'
#      22 # station = 'Byrd'
# ---> 24 ax.plot(x=ds_climate_nearest_stacked_june['Time'],
#      25         y=c_corrected,
#      26         alpha=0.7,
#      27         label='Climate Model',
#      28         marker='x',
#      29         ms=1,
#      30         color='tab:orange',
#      31         linewidth=1.0)
#      33 ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
#      34                                                                                                 hue='Station',
#      35                                                                                                 alpha=0.7,
#    (...)
#      39                                                                                                 color='tab:blue',
#      40                                                                                                 linewidth=1.5)
#      42 ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')
#
# File ~/miniconda3/envs/BCA/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/miniconda3/envs/BCA/lib/python3.13/site-packages/matplotlib/axes/_base.py:231, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     229 for pos_only in "xy":
#     230     if pos_only in kwargs:
# --> 231         raise _api.kwarg_error(self.command, pos_only)
#     233 if not args:
#     234     return
#
# TypeError: plot() got an unexpected keyword argument 'x'

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )


fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

station = 'Manuela'
# station = 'Byrd'

ax.plot(ds_climate_nearest_stacked_june['Time'],
        y=c_corrected,
        alpha=0.7,
        label='Climate Model',
        marker='x',
        ms=1,
        color='tab:orange',
        linewidth=1.0)

ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                hue='Station',
                                                                                                alpha=0.7,
                                                                                                label='Weather Station',
                                                                                                marker='x',
                                                                                                ms=1,
                                                                                                color='tab:blue',
                                                                                                linewidth=1.5)

ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')

ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)#,rotation = 90)
ax.set_ylabel('Temperature')
ax.set_xlabel('Time')
ax.legend()
ax.set_title('')

plt.tight_layout()
plt.show()















ds_climate_nearest_stacked_june['Corrected_Temperature'] = (
    ('Time'),
    c_corrected,
)

ds_climate_coarse_june_stacked_landonly['exp_truth_posterior_predictive_realisations_dualprocess_mean'] = (
    ('X'),
    scenario['truth_posterior_predictive_realisations_dualprocess_mean'].mean(axis=0))

fig, axs = plt.subplots(2, 1, figsize=(10, 7), dpi=300)



for ax,station in zip(axs,['Manuela','Byrd']):
    ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                    hue='Station',
                                                                                                    alpha=0.7,
                                                                                                    label='Weather Station',
                                                                                                    marker='x',
                                                                                                    ms=2)
    ds_climate_nearest_stacked.sel(Nearest_Station = station).where(ds_climate_nearest_stacked['month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                                                    hue='Station',
                                                                                                                                    alpha=0.7,
                                                                                                                                    label='Climate Model',
                                                                                                                                    marker='x',
                                                                                                                                    ms=2)

    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)#,rotation = 90)
    ax.set_ylabel('Temperature')
    ax.set_xlabel('Time')
    ax.legend()
    ax.set_title('')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 24
#      21 station = 'Manuela'
#      22 # station = 'Byrd'
# ---> 24 ax.plot(ds_climate_nearest_stacked_june['Time'],
#      25         y=c_corrected,
#      26         alpha=0.7,
#      27         label='Climate Model',
#      28         marker='x',
#      29         ms=1,
#      30         color='tab:orange',
#      31         linewidth=1.0)
#      33 ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
#      34                                                                                                 hue='Station',
#      35                                                                                                 alpha=0.7,
#    (...)
#      39                                                                                                 color='tab:blue',
#      40                                                                                                 linewidth=1.5)
#      42 ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')
#
# File ~/miniconda3/envs/BCA/lib/python3.13/site-packages/matplotlib/axes/_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1536 """
#    1537 Plot y versus x as lines and/or markers.
#    1538
#    (...)
#    1776 (``'green'``) or hex strings (``'#008000'``).
#    1777 """
#    1778 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1779 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1780 for line in lines:
#    1781     self.add_line(line)
#
# File ~/miniconda3/envs/BCA/lib/python3.13/site-packages/matplotlib/axes/_base.py:231, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     229 for pos_only in "xy":
#     230     if pos_only in kwargs:
# --> 231         raise _api.kwarg_error(self.command, pos_only)
#     233 if not args:
#     234     return
#
# TypeError: plot() got an unexpected keyword argument 'y'

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )


fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

station = 'Manuela'
# station = 'Byrd'

ax.plot(ds_climate_nearest_stacked_june['Time'],
        c_corrected,
        alpha=0.7,
        label='Climate Model',
        marker='x',
        ms=1,
        color='tab:orange',
        linewidth=1.0)

ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                hue='Station',
                                                                                                alpha=0.7,
                                                                                                label='Weather Station',
                                                                                                marker='x',
                                                                                                ms=1,
                                                                                                color='tab:blue',
                                                                                                linewidth=1.5)

ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')

ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)#,rotation = 90)
ax.set_ylabel('Temperature')
ax.set_xlabel('Time')
ax.legend()
ax.set_title('')

plt.tight_layout()
plt.show()















ds_climate_nearest_stacked_june['Corrected_Temperature'] = (
    ('Time'),
    c_corrected,
)

ds_climate_coarse_june_stacked_landonly['exp_truth_posterior_predictive_realisations_dualprocess_mean'] = (
    ('X'),
    scenario['truth_posterior_predictive_realisations_dualprocess_mean'].mean(axis=0))

fig, axs = plt.subplots(2, 1, figsize=(10, 7), dpi=300)



for ax,station in zip(axs,['Manuela','Byrd']):
    ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                    hue='Station',
                                                                                                    alpha=0.7,
                                                                                                    label='Weather Station',
                                                                                                    marker='x',
                                                                                                    ms=2)
    ds_climate_nearest_stacked.sel(Nearest_Station = station).where(ds_climate_nearest_stacked['month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                                                    hue='Station',
                                                                                                                                    alpha=0.7,
                                                                                                                                    label='Climate Model',
                                                                                                                                    marker='x',
                                                                                                                                    ms=2)

    ax.set_xticks(xticks)
    ax.set_xticklabels(xticklabels)#,rotation = 90)
    ax.set_ylabel('Temperature')
    ax.set_xlabel('Time')
    ax.legend()
    ax.set_title('')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 75
#      52 plt.show()
#      68 ds_climate_nearest_stacked_june['Corrected_Temperature'] = (
#      69     ('Time'),
#      70     c_corrected,
#      71 )
#      73 ds_climate_coarse_june_stacked_landonly['exp_truth_posterior_predictive_realisations_dualprocess_mean'] = (
#      74     ('X'),
# ---> 75     scenario['truth_posterior_predictive_realisations_dualprocess_mean'].mean(axis=0))
#      77 fig, axs = plt.subplots(2, 1, figsize=(10, 7), dpi=300)
#      81 for ax,station in zip(axs,['Manuela','Byrd']):
#
# NameError: name 'scenario' is not defined

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )


fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

station = 'Manuela'
# station = 'Byrd'

ax.plot(ds_climate_nearest_stacked_june['Time'],
        c_corrected,
        alpha=0.7,
        label='Climate Model',
        marker='x',
        ms=1,
        color='tab:orange',
        linewidth=1.0)

ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                hue='Station',
                                                                                                alpha=0.7,
                                                                                                label='Weather Station',
                                                                                                marker='x',
                                                                                                ms=1,
                                                                                                color='tab:blue',
                                                                                                linewidth=1.5)

ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')

ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)#,rotation = 90)
ax.set_ylabel('Temperature')
ax.set_xlabel('Time')
ax.legend()
ax.set_title('')

plt.tight_layout()
plt.show()

# %%
ds_climate_nearest_stacked_june
ds_aws_stacked_june
from scipy.stats import norm

cdf_c = norm.cdf(
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'],
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].mean(),
    ds_climate_nearest_stacked_june.sel(Nearest_Station=station)['Temperature'].std(),
)

c_corrected = norm.ppf(
        cdf_c,
        ds_aws_stacked_june.sel(Station=station)['Temperature'].mean(),
        ds_aws_stacked_june.sel(Station=station)['Temperature'].std(),
    )


fig, ax = plt.subplots(1, 1, figsize=(10, 5), dpi=300)

station = 'Manuela'
# station = 'Byrd'

ax.plot(ds_climate_nearest_stacked_june['Time'],
        c_corrected,
        alpha=0.7,
        label='Corrected Climate Model',
        marker='x',
        ms=1,
        color='tab:orange',
        linewidth=1.0)

ds_aws_stacked.sel(Station = station).where(ds_aws_stacked['Month']==month,drop=True)['Temperature'].plot(ax=ax,
                                                                                                hue='Station',
                                                                                                alpha=0.7,
                                                                                                label='Weather Station',
                                                                                                marker='x',
                                                                                                ms=1,
                                                                                                color='tab:blue',
                                                                                                linewidth=1.5)

ax.annotate('June',xy=(0.03,0.95),xycoords='axes fraction')

ax.set_xticks(xticks)
ax.set_xticklabels(xticklabels)#,rotation = 90)
ax.set_ylabel('Temperature')
ax.set_xlabel('Time')
ax.legend()
ax.set_title('')

plt.tight_layout()
plt.show()
